-- %%
%fs ls abfss://formula1@deacoursedl1.dfs.core.windows.net/

-- %%
CREATE CATALOG IF NOT EXISTS formula1 
MANAGED LOCATION 'abfss://formula1@deacoursedl1.dfs.core.windows.net/';

-- %%
SHOW CATALOGS

-- %%
-- Create a location accessed using the abfss_remote_cred credential
CREATE EXTERNAL LOCATION IF NOT EXISTS `folmula1-ext` URL 'abfss://formula1@deacoursedl1.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL `dea-course-sc`)
    COMMENT 'Formula1 external location';

-- %%
DROP SCHEMA formula1.landing CASCADE;

-- %%
CREATE SCHEMA IF NOT EXISTS formula1.landing;

CREATE SCHEMA IF NOT EXISTS formula1.bronze MANAGED LOCATION 'abfss://formula1@deacoursedl1.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS formula1.silver MANAGED LOCATION 'abfss://formula1@deacoursedl1.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS formula1.gold MANAGED LOCATION 'abfss://formula1@deacoursedl1.dfs.core.windows.net/gold';

-- DROP SCHEMA formula1.landing

-- %%
-- Create an external volume on the specified location with comment
CREATE EXTERNAL VOLUME IF NOT EXISTS formula1.landing.files
    LOCATION 'abfss://formula1@deacoursedl1.dfs.core.windows.net/raw/'
    COMMENT 'This is my example external volume on ADLS Gen2'

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StructType,StructField,IntegerType,StringType,DateType

# %%
# %run "../00-common/02.bronze-helpers"

# %%
# %run "../00-common/01.environment-config"

# %%
constructors_schema = """
constructorId STRING,
name STRING,
nationality STRING,
url STRING
"""

# %%
constructors_file_path = f"{landing_folder_path}/constructors.json"

constructors_df = spark.read \
    .format("json") \
    .option("mode", "FAILFAST") \
    .option("header","true") \
    .schema(constructors_schema) \
    .load(constructors_file_path)

# %%
constructors_df = add_ingestion_metadata(constructors_df)

# %%
constructors_table = f'{catalog_name}.{bronze_schema}.constructors'
constructors_df.write.mode("overwrite").saveAsTable(constructors_table)

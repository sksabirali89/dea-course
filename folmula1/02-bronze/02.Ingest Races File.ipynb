# %%
from pyspark.sql import functions as F
from pyspark.sql.types import StructType,StructField,IntegerType,StringType,DateType

# %%
# %run "../00-common/02.bronze-helpers"

# %%
# %run "../00-common/01.environment-config"

# %%
races_schema = StructType([
    StructField("season",IntegerType()),
    StructField("round",IntegerType()),
    StructField("url",StringType()),
    StructField("raceName",StringType()),
    StructField("date",DateType()),
    StructField("circuitId",StringType())
])

# %%
races_file_path = f"{landing_folder_path}/races.csv"

races_df = spark.read \
    .format("csv") \
    .option("mode", "FAILFAST") \
    .option("header","true") \
    .schema(races_schema) \
    .load("/Volumes/formula1/landing/files/races.csv")

# %%
races_df = add_ingestion_metadata(races_df)

# %%
races_table = f'{catalog_name}.{bronze_schema}.races'
races_df.write.mode("overwrite").saveAsTable(races_table)

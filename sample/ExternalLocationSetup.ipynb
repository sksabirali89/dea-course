# %%
# %fs ls 'abfss://demo@deacoursedl1.dfs.core.windows.net/'

# %%
# %sql
-- Create a location accessed using the dea-course-sc credential
CREATE EXTERNAL LOCATION IF NOT EXISTS `dea-course-dl-demo-ext`
URL 'abfss://demo@deacoursedl1.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `dea-course-sc`)
COMMENT 'External location of demo container';

# %%
# %sql
-- If files already exist in the external location
CREATE TABLE IF NOT EXISTS dea_course_dev.default.demo
USING DELTA
LOCATION 'abfss://demo@deacoursedl1.dfs.core.windows.net/circuits.csv'

# %%
from pyspark.sql import Row


data = [Row(id=1, name=123), Row(id=2, name=456), Row(id=3, name=347)]
df = spark.createDataFrame(data)
display(df)

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True)
])

data = [(1, "Alice"), (2, "Bob"), (3, "Charlie")]
df_with_schema = spark.createDataFrame(data, schema)
display(df_with_schema)

# %%
# List all scopes
dbutils.secrets.listScopes()

# List all secrets inside a specific scope
# dbutils.secrets.list(scope="dea-course-kv-scope")

# %%
# Replace 'your-secret-name' with the actual secret name from Key Vault
secret_value = dbutils.secrets.get(scope="dea-course-kv-scope", key="dea-course-catalog-name")

print(secret_value)  # Will print [REDACTED] — that's normal and secure

# %%
# %%sql
# SELECT * FROM samples.bakehouse.media_customer_reviews;

# %%
DF = spark.sql("SELECT * FROM samples.bakehouse.media_gold_reviews_chunked")
display(DF)
